# %% [markdown]
# ## Setting up Google Earth Engine for Python Jupyter Notebook

# %%
import ee

# Authenticate (only needed once)
ee.Authenticate()
# Out:
# True

# %%
# Initialize Earth Engine
ee.Initialize(project='geog-581-483717')
